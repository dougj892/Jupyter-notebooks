# %% [markdown]
# # Import and clean up the 3ie data

# %%
# import and patch together the 3 files with the 3ie impact evaluation data
import pandas as pd
import numpy as np
import os

os.chdir("/Users/douglasjohnson/Documents/code/datasets/")

# import the datasets
first_1000 = pd.read_csv("3ie/first_1000")
second_600 = pd.read_csv("3ie/second_600")
third_1200 = pd.read_csv("3ie/third_1200")
remaining = pd.read_csv("3ie/3ie_final.csv")

# merge them 
df = pd.concat([first_1000,second_600,third_1200, remaining])

df.to_csv("/Users/douglasjohnson/Documents/code/datasets/3ie/3ie_combined_raw.csv")

# %%
df['Country'] =df['Country'].astype('str')

# %%
tempdf=pd.DataFrame(temp)
tempdf = tempdf.sort_index()

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')
    
print_full(tempdf)
# Out:
#                                                     Country
#  None specified                                          23
# Afghanistan                                              21
# Albania                                                   8
# Albania, Algeria, Armenia, Azerbaijan, Belarus,...        1
# Albania, Armenia, Azerbaijan, Belarus, Bosnia a...        1
# Albania, Armenia, Azerbaijan, Belarus, Bosnia a...        1
# Algeria, Angola, Benin, Botswana, Burkina Faso,...        1
# American Samoa                                            1
# Angola                                                    2
# Antigua and Barbuda                                       1
# Argentina                                                65
# Argentina, Bolivia, Brazil                                1
# Argentina, Bolivia, Brazil, Chile, Colombia, Co...        1
# Argentina, Bolivia, Brazil, Chile, Colombia, Do...        1
# Argentina, Brazil, Chile, Panama                          1
# ...
