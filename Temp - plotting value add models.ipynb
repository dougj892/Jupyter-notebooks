# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
y = []
y.append(4)
beta = .4
eta = 2.5
for i in range(1,11):
    y.append(y[i-1]*beta+eta)

plt.plot(range(0,11),y)

# %%
y
# Out:
# [4,
#  4.1,
#  4.14,
#  4.156,
#  4.1624,
#  4.16496,
#  4.165984,
#  4.1663936,
#  4.16655744,
#  4.166622976,
#  4.1666491904]
